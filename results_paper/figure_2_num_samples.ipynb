# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Training as a function of the number of samples

# %%
import torch
from wassa_functions import performance_as_a_function_of_dataset_parameters
from wassa_training import get_training_parameters
from wassa_plots import plot_results_std
import matplotlib.pyplot as plt
import numpy as np

# %%
date = '2025-10-15'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
device = 'cuda:0'

# %%
dataset_parameters = {
    'seed' : 666,
    
    'N_pre' : 260, # number of neurons
    'N_timesteps' : 250, # number of timesteps for the raster plot (in ms)
    'N_samples' : 60, # total number of samples in the dataset
    'N_sms' : 1, # number of structured spiking motifs

    'temporal_jitter' : 10, # temporal jitter for the spike generation in motifs
    'dropout_proba' : 0, # probabilistic participations of the different neurons to the spikingconvient motif
    'additive_noise' : .1, # percentage of background noise/spontaneous activity
    'min_warping_coef' : 1, # coefficient for time warping
}
dataset_parameters.update({'N_involved':dataset_parameters['N_pre']*torch.ones(dataset_parameters['N_sms'])}) # number of neurons involved in the spiking motif
dataset_parameters.update({'proba_sms' : torch.ones(dataset_parameters['N_sms'])/dataset_parameters['N_sms']}) # probability of apparition of the different spiking motif

# %%
training_parameters_emd = {
    'kernel_size' : (dataset_parameters['N_sms'], dataset_parameters['N_pre'], dataset_parameters['N_timesteps']),
    'loss_type' : 'emd',
    'activation' : 'emd like',
    'sigmoid' : False,
    'kernels_norm' : 2,
    'N_learnsteps' : 2000,
    'learning_rate' : .1,
    'penalty_type' : [None],
    'lambda' : [0],
    'batch_size' : None,
    'do_bias' : False,
    'weight_init' : 'flat',
    'normalize_input' : True
}

# %%
training_parameters_mse = {
    'kernel_size' : (dataset_parameters['N_sms'], dataset_parameters['N_pre'], dataset_parameters['N_timesteps']),
    'loss_type' : 'mse',
    'activation' : 'conv',
    'sigmoid' : False,
    'kernels_norm' : 2,
    'N_learnsteps' : 2000,
    'learning_rate' : .05,
    'penalty_type' : [None],
    'lambda' : [0],
    'batch_size' : None,
    'do_bias' : False,
    'weight_init' : 'flat',
    'normalize_input' : True
}

# %%
dataset_parameters['N_samples'] = 10
i, k = 0, 1
record_path = '../simulations/'
metric_names = ['training loss', 'kernels similarity']
training_params = training_parameters_emd
model_name = record_path + get_dataset_parameters(dataset_parameters) + str(i) + str(k) + get_training_parameters(training_params)
sm, dataset_input, dataset_output = generate_dataset(dataset_parameters, device=device)
trainsets, testsets, indices = kfold_dataset(dataset_input.sum(axis=0),k=k)
autoencoder = WassA(training_params, device=device)
autoencoder, training_metrics, metric_names = learn_motifs(autoencoder,trainsets[0],testsets[0],training_params,model_name,metric_names,sm,online_plots = True)
plot_results(training_metrics, metric_names, autoencoder, trainsets[0], model=sm, spike_times = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       4 metric_names = ['training loss', 'kernels similarity']
#       5 training_params = training_parameters_emd
# ----> 6 model_name = record_path + get_dataset_parameters(dataset_parameters) + str(i) + str(k) + get_training_parameters(training_params)
#       7 sm, dataset_input, dataset_output = generate_dataset(dataset_parameters, device=device)
#       8 trainsets, testsets, indices = kfold_dataset(dataset_input.sum(axis=0),k=k)
#
# NameError: name 'get_dataset_parameters' is not defined

# %%
dataset_variables = {
'N_samples' : torch.logspace(.3,3,10).int().tolist(),
}

# %%
file_name = '../simulations/results_samples'+get_training_parameters(training_parameters_emd)+get_training_parameters(training_parameters_mse)

training_metrics = ['training loss', 'testing loss', 'explained variance']
synthetic_metrics = ['kernels similarity', 'mean timings similarity', 'mse', 'emd', 'emd mean timings','mean time diff']
n_iter = 100
kfold = 1
do_seqnmf = False
results, _ = performance_as_a_function_of_dataset_parameters(file_name, dataset_parameters, training_parameters_emd, training_parameters_mse, dataset_variables, training_metrics, synthetic_metrics, n_iter = n_iter, kfold=kfold, do_seqnmf = do_seqnmf, device=device)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# torch.Size([1, 1, 260])
# /home/antoine/Documents/wassa/results_paper/wassa_training.py:117: UserWarning: var(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /opt/conda/conda-bld/pytorch_1729647378361/work/aten/src/ATen/native/ReduceOps.cpp:1823.)
#   ev = 1-torch.var(testing_set-testset_hat)/torch.var(testing_set)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       6 kfold = 1
#       7 do_seqnmf = False
# ----> 8 results, _ = performance_as_a_function_of_dataset_parameters(file_name, dataset_parameters, training_parameters_emd, training_parameters_mse, dataset_variables, training_metrics, synthetic_metrics, n_iter = n_iter, kfold=kfold, do_seqnmf = do_seqnmf, device=device)
#
# File ~/Documents/wassa/results_paper/wassa_functions.py:116, in performance_as_a_function_of_dataset_parameters(file_name, dataset_parameters, training_parameters_emd, training_parameters_mse, dataset_variables, training_metrics, synthetic_metrics, seeds, n_iter, kfold, do_seqnmf, plot, verbose, device)
#     114 world_parameters['seed'] = seeds[i].item()
#     115 sm, dataset_input, dataset_output = generate_dataset(world_parameters, verbose=False, device=device)
# --> 116 results[list_indices+[[0],[i]]] = unsupervised_learning([params_mse],[sm, dataset_input.sum(axis=0)],training_metrics, get_dataset_parameters(world_parameters, include_samples=True),k_fold=kfold,synthetic_metrics=synthetic_metrics,verbose=verbose, device=device)
#     117 results[list_indices+[[1],[i]]] = unsupervised_learning([params_emd],[sm, dataset_input.sum(axis=0)],training_metrics, get_dataset_parameters(world_parameters, include_samples=True),k_fold=kfold,synthetic_metrics=synthetic_metrics,verbose=verbose, device=device)
#     118 if do_seqnmf:
#
# File ~/Documents/wassa/results_paper/wassa_training.py:173, in unsupervised_learning(parameters, dataset, metric_names, dataset_name, k_fold, n_iter, last_steps, synthetic_metrics, record_path, device, verbose)
#     171         results[i,k,:] = training_metrics[n_last_steps:].mean(axis=0)
#     172     else:
# --> 173         similarities_gt = get_similarity(sm, autoencoder, testset, synthetic_metrics, spike_times = spike_times)
#     174         results[i,k] = torch.hstack([training_metrics[n_last_steps:].mean(axis=0),similarities_gt])
#     175 else:
#
# File ~/Documents/wassa/results_paper/wassa_metrics.py:119, in get_similarity(sm, autoencoder, testset_input, metric_names, spike_times, verbose)
#     117     results[ind_m] = kernels_diff(sm.SMs, learnt_weights, 'mse')
#     118 if metric == 'emd':
# --> 119     results[ind_m] = kernels_diff(sm.SMs, learnt_weights, 'emd')
#     120 if metric == 'emd mean timings':
#     121     results[ind_m] = kernels_diff(mean_timings, learnt_weights, 'emd')
#
# File ~/Documents/wassa/results_paper/wassa_metrics.py:62, in kernels_diff(true_kernels, learnt_kernels, metric, norm)
#      59     learnt_matrix = learnt_kernels.unsqueeze(1).repeat(1,n_motifs,1,1)
#      60     error_matrix = torch_cdf_loss(true_matrix,learnt_matrix,'ignore',False).mean(axis=-1)
# ---> 62 return find_closest(error_matrix,'min')
#
# File ~/Documents/wassa/results_paper/wassa_utils.py:72, in find_closest(matrix, max_or_min)
#      68 def find_closest(matrix,max_or_min):
#      69     # size of the matrix is MxN where N is the number of trained kernels and M is the number of ground truth motifs
#      70     # loop over the different motifs to see if similarity is good with different kernels
#      71     value = 0
# ---> 72     for l_k in range(min(matrix.shape)):
#      73         if max_or_min=='max':
#      74             ind = torch.where(matrix==matrix.max())
#
# ValueError: min() iterable argument is empty

# %%
name_metrics = ['kernels similarity', 'mean timings similarity', 'mean time diff']
name_methods = ['MSE','EMD']
colors = ['darkolivegreen','blue','purple','orangered']
xlabel = '# samples'
quantile = True

fig, ax = plt.subplots(1,3, figsize=(12,4),constrained_layout = True)
for i in range(len(name_metrics)):
    for m in range(len(name_methods)):
        ymin, ymax = 0, 1
        xmin, xmax = 0, 1000
        do_legend, log_x, log_y = False, True, False
        if i==0:
            ylabel = 'similarity value'
        elif i==2:
            ylabel = 'absolute timing difference'
            ymax = None
        else:
            ymax = .5
            ylabel = 'mean timings similarity'
            log_y = False
            do_legend = True
        ax[i] = plot_results_std(ax[i],results[:,m],dataset_variables['N_samples'],training_metrics+synthetic_metrics,xlabel,name_metrics[i],name_methods[m],colors[m],ymax=ymax,ymin=ymin,ylabel=ylabel,do_legend=do_legend,log_x=log_x,log_y=log_y,quantile=quantile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 23
#      21     log_y = False
#      22     do_legend = True
# ---> 23 ax[i] = plot_results_std(ax[i],results[:,m],dataset_variables['N_samples'],training_metrics+synthetic_metrics,xlabel,name_metrics[i],name_methods[m],colors[m],ymax=ymax,ymin=ymin,ylabel=ylabel,do_legend=do_legend,log_x=log_x,log_y=log_y,quantile=quantile)
#
# NameError: name 'results' is not defined

# %%
#fig.tight_layout()
fig.savefig('../figures/results_samples.pdf', bbox_inches = 'tight')
