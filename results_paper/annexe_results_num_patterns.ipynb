# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Training as a function of the number of patterns

# %%
import torch
from wassa_functions import performance_as_a_function_of_dataset_parameters
from dataset_generation import get_dataset_parameters, generate_dataset, kfold_dataset
from wassa_training import get_training_parameters, learn_motifs
from wassa_plots import plot_results_std, plot_results
import matplotlib.pyplot as plt
import numpy as np
from wassa import WassA

# %%
date = '2025-10-15'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
device = 'cuda:1'

# %%
dataset_parameters = {
    'seed' : 91,
    
    'N_pre' : 260, # number of neurons
    'N_timesteps' : 250, # number of timesteps for the raster plot (in ms)
    'N_samples' : 100, # total number of samples in the dataset
    'N_sms' : 4, # number of structured spiking motifs

    'temporal_jitter' : 1, # temporal jitter for the spike generation in motifs
    'dropout_proba' : 0, # probabilistic participations of the different neurons to the spiking motif
    'additive_noise' : .1, # percentage of background noise/spontaneous activity
    'min_warping_coef' : 1, # coefficient for time warping
}
dataset_parameters.update({'N_involved':dataset_parameters['N_pre']*torch.ones(dataset_parameters['N_sms'])}) # number of neurons involved in the spiking motif
dataset_parameters.update({'proba_sms' : torch.ones(dataset_parameters['N_sms'])/dataset_parameters['N_sms']}) # probability of apparition of the different spiking motif

# %%
training_parameters_emd = {
    'kernel_size' : (dataset_parameters['N_sms'], dataset_parameters['N_pre'], dataset_parameters['N_timesteps']),
    'loss_type' : 'emd',
    'activation' : 'conv',
    'sigmoid' : False,
    'kernels_norm' : True,
    'N_learnsteps' : 2000,
    'learning_rate' : .01,
    'penalty_type' : ['factors_cc'],
    'lambda' : [.01],
    'batch_size' : None,
    'do_bias' : False,
    'weight_init' : None,
    'normalize_input' : True
}

# %%
training_parameters_mse = {
    'kernel_size' : (dataset_parameters['N_sms'], dataset_parameters['N_pre'], dataset_parameters['N_timesteps']),
    'loss_type' : 'mse',
    'activation' : 'conv',
    'sigmoid' : False,
    'kernels_norm' : 2,
    'N_learnsteps' : 2000,
    'learning_rate' : .05,
    'penalty_type' : ['factors_cc'],
    'lambda' : [.01],
    'batch_size' : None,
    'do_bias' : False,
    'weight_init' : None,
    'normalize_input' : True
}

# %%
i, k = 0, 1
record_path = '../simulations/'
metric_names = ['training loss', 'kernels similarity', 'kernels correlation']
training_params = training_parameters_emd
model_name = record_path + get_dataset_parameters(dataset_parameters) + str(i) + str(k) + get_training_parameters(training_params)
sm, dataset_input, dataset_output = generate_dataset(dataset_parameters, device=device)
trainsets, testsets, indices = kfold_dataset(dataset_input.sum(axis=0),k=k)
autoencoder = WassA(training_params, device=device)
autoencoder, training_metrics, metric_names = learn_motifs(autoencoder,trainsets[0],testsets[0],training_params,model_name,metric_names,sm,online_plots = True)
plot_results(training_metrics, metric_names, autoencoder, trainsets[0], model=sm, spike_times = None)
# Out:
# ../synthetic_data_no_bernoulli/generative_model_912602504100.11260.0260.0260.0260.00.250.250.250.25
# with k=1, train and test sets are the same
# ../simulations/912602504100.11260.0260.0260.0260.00.250.250.250.25014260250emdconvFalseTrue20000.01factors_cc0.01NoneFalseNoneTrue00

# %%
dataset_variables = {
'N_sms' : torch.linspace(1,10,10).int().tolist(),
}

# %%
file_name = '../simulations/results_patterns'+get_training_parameters(training_parameters_emd)+get_training_parameters(training_parameters_mse)
training_metrics = ['training loss', 'testing loss', 'explained variance']
synthetic_metrics = ['kernels similarity', 'mean timings similarity', 'mse', 'emd', 'emd mean timings','mean time diff']
n_iter = 100
kfold = 1
do_seqnmf = False
results, _ = performance_as_a_function_of_dataset_parameters(file_name, dataset_parameters, training_parameters_emd, training_parameters_mse, dataset_variables, training_metrics, synthetic_metrics, n_iter = n_iter, kfold=kfold, do_seqnmf = do_seqnmf, device=device)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# ../simulations/02602501003100.11260.0260.0260.00.33333334326744080.33333334326744080.3333333432674408003260250mseconvFalse220000.05factors_cc0.01NoneFalseNoneTrue00
#   0%|          | 0/1 [00:00<?, ?it/s]
# ../simulations/02602501003100.11260.0260.0260.00.33333334326744080.33333334326744080.3333333432674408003260250emdconvFalseTrue20000.01factors_cc0.01NoneFalseNoneTrue00
#   0%|          | 0/1 [00:00<?, ?it/s]
# ../simulations/12602501003100.11260.0260.0260.00.33333334326744080.33333334326744080.3333333432674408003260250mseconvFalse220000.05factors_cc0.01NoneFalseNoneTrue00
#   0%|          | 0/1 [00:00<?, ?it/s]
# ../simulations/12602501003100.11260.0260.0260.00.33333334326744080.33333334326744080.3333333432674408003260250emdconvFalseTrue20000.01factors_cc0.01NoneFalseNoneTrue00
#   0%|          | 0/1 [00:00<?, ?it/s]
# ../simulations/22602501003100.11260.0260.0260.00.33333334326744080.33333334326744080.3333333432674408003260250mseconvFalse220000.05factors_cc0.01NoneFalseNoneTrue00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 7
#       5 kfold = 1
#       6 do_seqnmf = False
# ----> 7 results, _ = performance_as_a_function_of_dataset_parameters(file_name, dataset_parameters, training_parameters_emd, training_parameters_mse, dataset_variables, training_metrics, synthetic_metrics, n_iter = n_iter, kfold=kfold, do_seqnmf = do_seqnmf, verbose=True, device=device)
#
# File ~/Documents/wassa/results_paper/wassa_functions.py:116, in performance_as_a_function_of_dataset_parameters(file_name, dataset_parameters, training_parameters_emd, training_parameters_mse, dataset_variables, training_metrics, synthetic_metrics, seeds, n_iter, kfold, do_seqnmf, plot, verbose, device)
#     114 world_parameters['seed'] = seeds[i].item()
#     115 sm, dataset_input, dataset_output = generate_dataset(world_parameters, verbose=False, device=device)
# --> 116 results[list_indices+[[0],[i]]] = unsupervised_learning([params_mse],[sm, dataset_input.sum(axis=0)],training_metrics, get_dataset_parameters(world_parameters, include_samples=True),k_fold=kfold,synthetic_metrics=synthetic_metrics,verbose=verbose, device=device)
#     117 results[list_indices+[[1],[i]]] = unsupervised_learning([params_emd],[sm, dataset_input.sum(axis=0)],training_metrics, get_dataset_parameters(world_parameters, include_samples=True),k_fold=kfold,synthetic_metrics=synthetic_metrics,verbose=verbose, device=device)
#     118 if do_seqnmf:
#
# File ~/Documents/wassa/results_paper/wassa_training.py:164, in unsupervised_learning(parameters, dataset, metric_names, dataset_name, k_fold, n_iter, last_steps, synthetic_metrics, record_path, device, verbose)
#     162 nan_condition = torch.isnan(autoencoder.weights.data).sum()==0
#     163 if 'mean time diff' in synthetic_metrics:
# --> 164     spike_times, errors = estimate_spike_times(autoencoder.weights.detach().cpu().numpy())
#     165 else:
#     166     spike_times = None
#
# File ~/Documents/wassa/results_paper/wassa_utils.py:155, in estimate_spike_times(all_weights, max_iteration, min_max_proba)
#     153     errors.append(0)
#     154 else:
# --> 155     popt, _ = curve_fit(gaussian_kernel, time_scale, all_weights[sm,neuron], p0=[max_proba,time,jitter], bounds = ((0,0,0), (1,n_timesteps, 1/(min_max_proba*np.sqrt(2*np.pi)))), maxfev=max_iteration)
#     156     error = ((all_weights[sm,neuron]-gaussian_kernel(time_scale,popt[0],popt[1],popt[2]))**2).mean()
#     157     spike_times.append(round(popt[1]))
#
# File ~/miniconda3/envs/wassa/lib/python3.12/site-packages/scipy/optimize/_minpack_py.py:988, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     985 if 'max_nfev' not in kwargs:
#     986     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 988 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     989                     **kwargs)
#     991 if not res.success:
#     992     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File ~/miniconda3/envs/wassa/lib/python3.12/site-packages/scipy/optimize/_lsq/least_squares.py:941, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     937     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     938                           max_nfev, x_scale, diff_step)
#     940 elif method == 'trf':
# --> 941     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     942                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     943                  tr_options.copy(), verbose)
#     945 elif method == 'dogbox':
#     946     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File ~/miniconda3/envs/wassa/lib/python3.12/site-packages/scipy/optimize/_lsq/trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File ~/miniconda3/envs/wassa/lib/python3.12/site-packages/scipy/optimize/_lsq/trf.py:374, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     370 f_true = f.copy()
#     372 cost = cost_new
# --> 374 J = jac(x, f)
#     375 njev += 1
#     377 if loss_function is not None:
#
# File ~/miniconda3/envs/wassa/lib/python3.12/site-packages/scipy/optimize/_lsq/least_squares.py:898, in least_squares.<locals>.jac_wrapped(x, f)
#     897 def jac_wrapped(x, f):
# --> 898     J = approx_derivative(fun, x, rel_step=diff_step, method=jac,
#     899                           f0=f, bounds=bounds, args=args,
#     900                           kwargs=kwargs, sparsity=jac_sparsity)
#     901     if J.ndim != 2:  # J is guaranteed not sparse.
#     902         J = np.atleast_2d(J)
#
# File ~/miniconda3/envs/wassa/lib/python3.12/site-packages/scipy/optimize/_numdiff.py:479, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     477     f0 = fun_wrapped(x0)
#     478 else:
# --> 479     f0 = np.atleast_1d(f0)
#     480     if f0.ndim > 1:
#     481         raise ValueError("`f0` passed has more than 1 dimension.")
#
# File ~/miniconda3/envs/wassa/lib/python3.12/site-packages/numpy/core/shape_base.py:19, in _atleast_1d_dispatcher(*arys)
#      12 from . import fromnumeric as _from_nx
#      15 array_function_dispatch = functools.partial(
#      16     overrides.array_function_dispatch, module='numpy')
# ---> 19 def _atleast_1d_dispatcher(*arys):
#      20     return arys
#      23 @array_function_dispatch(_atleast_1d_dispatcher)
#      24 def atleast_1d(*arys):
#
# KeyboardInterrupt:

# %%
name_metrics = ['kernels similarity', 'mean timings similarity', 'mean time diff']
name_methods = ['MSE','EMD']
colors = ['darkolivegreen','blue','purple','orangered']
xlabel = '# patterns'
ymin = 0
quantile = True
fig, ax = plt.subplots(1,len(name_metrics), figsize=(16,5))
for i in range(len(name_metrics)):
    for m in range(len(name_methods)):
        if i==0:
            ylabel = 'similarity value'
            ymin, ymax = 0, 1
            do_legend, log_x, log_y = False, False, False
        elif i==2:
            ylabel = 'averaged timing difference'
            ymin, ymax = 0, None
            do_legend, log_x, log_y = False, False, False
        else:
            ylabel = None
            ymin, ymax = 0, 1
            do_legend, log_x, log_y = True, False, False
        ax[i] = plot_results_std(ax[i],results[:,m],dataset_variables['N_sms'],training_metrics+synthetic_metrics,xlabel,name_metrics[i],name_methods[m],colors[m],ymax=ymax,ymin=ymin,ylabel=ylabel,do_legend=do_legend,log_x=log_x,log_y=log_y,quantile=quantile)

# %% [raw]
# fig.tight_layout()
# fig.savefig('../figures/results_motifs.pdf', bbox_inches = 'tight')
